# %% [markdown]
# Preparation

# %%
# importing pytorch
import torch
print(torch.__version__)
# Out:
# 2.2.1+cu121

# %%
# installing pointnet++
# !pip install ninja
# !git clone https://github.com/erikwijmans/Pointnet2_PyTorch
# %cd /content/Pointnet2_PyTorch
# !python setup.py install
# Out:
# ...
# Cloning into 'Pointnet2_PyTorch'...
# remote: Enumerating objects: 706, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 706 (delta 0), reused 1 (delta 0), pack-reused 703
# Receiving objects: 100% (706/706), 976.27 KiB | 3.34 MiB/s, done.
# Resolving deltas: 100% (391/391), done.
# /content/Pointnet2_PyTorch
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
# ...

# %%
# install minimal requirements (pytorch is already installed in colab)
# !pip install timm==0.5.4 wandb tqdm h5py==3.6.0 protobuf==3.20.1 lmdb==1.2.1 msgpack-numpy==0.4.7.1 scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 42.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.5/881.5 kB 43.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 26.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 34.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.5 MB/s eta 0:00:00
# ...
#   Created wheel for lmdb: filename=lmdb-1.2.1-cp310-cp310-linux_x86_64.whl size=265649 sha256=64875f7db043673d539ed975216cb764b2271652021e60042fac0c8b359de0cb
#   Stored in directory: /root/.cache/pip/wheels/ae/36/fc/13e586283759d30c3efc3d0b917b2c5f1b69d171de8b7ed204
# ...

# %%
# connecting Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/antoalli/SemNov_AML_DAAI_23-24

# %%
# Move to the project directory after Git clone
# %cd /content/SemNov_AML_DAAI_23-24
# Out:
# /content/SemNov_AML_DAAI_23-24

# %%
#downloading models data
# !sh download_data.sh
# Out:
# ...
# ============Downloading ModelNet40 + OOD Splits in
# --2024-04-12 12:32:36--  https://www.dropbox.com/s/c2x3h59nxprjs21/modelnet40_normal_resampled.tar?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/c2x3h59nxprjs21/modelnet40_normal_resampled.tar [following]
# --2024-04-12 12:32:36--  https://www.dropbox.com/s/dl/c2x3h59nxprjs21/modelnet40_normal_resampled.tar
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc583a20754a8dcfe1268363adf0.dl-eu.dropboxusercontent.com/cd/0/get/CQ7tgB5K3-n-0xparr7M-mvWQrJmqNj5mHVMPSUsX2PtUHP1TSNeKhxKMJ2ZRJbHwfGy797doquBQe5kP7btyFqZlLdeZcCpG1wsYtKRD27VQSYFTr1pXbRbqyRo489OY1Z--0HBiJC-0qLaxFgJmYnz/file?dl=1# [following]
# ...

# %% [markdown]
# Trainings and Evaluations

# %%
# Training DGCNN encoder with discriminative (and CE(l2)) method and SR1
# !python classifiers/trainer_cla_md.py --config cfgs/dgcnn-cla.yaml --exp_name DGCNN_CE_SR1 --src SR1 --loss CE --wandb_proj AML_DAAI_proj23_24_test

# %%
# Evaluation DCGNN, discriminative (and CE(l2)) SR1
# !python classifiers/trainer_cla_md.py --config cfgs/dgcnn-cla.yaml --exp_name DGCNN_CE_SR1 --src SR1 --loss CE --wandb_proj AML_DAAI_proj23_24_test -mode eval --ckpt_path outputs/DGCNN_CE_SR1/models/model_last.pth

# %%
#Training DGCNN encoder with discriminative (and CE(l2)) method and SR2
# !python classifiers/trainer_cla_md.py --config cfgs/dgcnn-cla.yaml --exp_name DGCNN_CE_SR2 --src SR2 --loss CE --wandb_proj AML_DAAI_proj23_24_test

# %%
# evaluation DCGNN, discriminative (and CE(l2)) SR2
# !python classifiers/trainer_cla_md.py --config cfgs/dgcnn-cla.yaml --exp_name DGCNN_CE_SR2 --src SR2 --loss CE --wandb_proj AML_DAAI_proj23_24_test -mode eval --ckpt_path outputs/DGCNN_CE_SR2/models/model_last.pth

# %%
#Training PN++ encoder with discriminative (and CE(l2)) method and SR1
# !python classifiers/trainer_cla_md.py --config cfgs/pn2-msg.yaml --exp_name PN2_CE_SR1 --src SR1 --loss CE --wandb_proj AML_DAAI_proj23_24_test

# %%
# Evaluation PN++, discriminative (and CE(l2)) SR1
# !python classifiers/trainer_cla_md.py --config cfgs/pn2-msg.yaml --exp_name PN2_CE_SR1 --src SR1 --loss CE --wandb_proj AML_DAAI_proj23_24_test -mode eval --ckpt_path outputs/PN2_CE_SR1/models/model_last.pth

# %%
#Training PN++ encoder with discriminative (and CE(l2)) method and SR2
# !python classifiers/trainer_cla_md.py --config cfgs/pn2-msg.yaml --exp_name PN2_CE_SR2 --src SR2 --loss CE --wandb_proj AML_DAAI_proj23_24_test

# %%
# Evaluation PN++, discriminative (and CE(l2)) SR2
# !python classifiers/trainer_cla_md.py --config cfgs/pn2-msg.yaml --exp_name PN2_CE_SR2 --src SR2 --loss CE --wandb_proj AML_DAAI_proj23_24_test -mode eval --ckpt_path outputs/PN2_CE_SR2/models/model_last.pth

# %% [markdown]
# Fail Analisis

# %%
# !rm -rf SemNov_AML_DAAI_23-24

# %%
# !git clone https://github.com/lukebikes/SemNov_AML_DAAI_23-24
# Out:
# Cloning into 'SemNov_AML_DAAI_23-24'...
# remote: Enumerating objects: 455, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 455 (delta 47), reused 45 (delta 34), pack-reused 379
# Receiving objects: 100% (455/455), 1.02 GiB | 37.14 MiB/s, done.
# Resolving deltas: 100% (183/183), done.
# Updating files: 100% (378/378), done.

# %%
# !pip install --upgrade https://github.com/unlimblue/KNN_CUDA/releases/download/0.2/KNN_CUDA-0.2-py3-none-any.whl

# %%
#Evaluation with Failcase on MSP and Distance based L2
# !python classifiers/trainer_cla_md2.py --config cfgs/dgcnn-cla.yaml --exp_name DGCNN_CE_SR1 --src SR1 --loss CE  -mode eval --ckpt_path outputs/DGCNN_CE_SR1/models/model_last.pth
# Out:
# Cannot import torchlars
# Cannot load RSCNN: No module named 'pointnet2_ops'
# Cannot load PCT: No module named 'pointnet2_ops'
# Cannot load PointMLP: No module named 'pointnet2_ops'
# Cannot load PointNet2: No module named 'pointnet2_ops'
# out-of-distribution eval - Modelnet -> SONN ..
# ...

# %% [markdown]
# Testing pre-trained models

# %%
# !pip install dgl
# !pip install torch_redstone
# !pip install einops
# !pip install --upgrade https://github.com/unlimblue/KNN_CUDA/releases/download/0.2/KNN_CUDA-0.2-py3-none-any.whl
# !pip install ninja==1.10.2.2
import shutil
# !sh download_models.sh

# %%
# G14 test
# !python /content/SemNov_AML_DAAI_23-24/G14_Eval.py --config cfgs/dgcnn-cla.yaml --exp_name Openshape_test_G14 --num_workers 2 --src SR1  --checkpoints_dir Pointbert_G14  --ckpt_path Pointbert_G14/model.pt  --script_mode eval

# %%
# L14 test
# !python /content/SemNov_AML_DAAI_23-24/L14_Eval.py --config cfgs/dgcnn-cla.yaml --exp_name Openshape_test_L14 --num_workers 2  --src SR1  --checkpoints_dir Pointbert_L14  --ckpt_path Pointbert_L14/model.pt  --script_mode eval

# %%
# B32 test
# !python /content/SemNov_AML_DAAI_23-24/B32_Eval.py --config cfgs/dgcnn-cla.yaml --exp_name Openshape_test_B32 --num_workers 2  --src SR1  --checkpoints_dir Pointbert_B32  --ckpt_path Pointbert_B32/model.pt  --script_mode eval
